# %% [markdown]
# # Super Scanner Software
# ## Get Hi-Re Photo
# Recovery the Hi-Res image from a image set wich contains Lo-Res photos of a sample illuminated sequentially with one LED of a grid at time. Simply **execute all cells below**.
#
# > **Note:** review the default settings of `generate_wave_vectors()` and `simulate_lores_set()` functions in in [fwdimaging.ipynb](jupyter-modules/fwdimaging.ipynb), give yours in the calls in the `get_photo()` in [phaseretrieval.ipynb](jupyter-modules/phaseretrieval.ipynb), save that notebook and restart the kernel here from **Kernel**&rarr;**Restart & Run All**.
#
# By default, the output directory is **out-img-hires** in **super-scanner-software**.

# %%
import phaseretrieval as fp
# Out:
# importing notebook from /home/marroquintoledo-l-lm/Descargas/super-scanner-software-s3/jupyter-modules/phaseretrieval.ipynb
# importing notebook from /home/marroquintoledo-l-lm/Descargas/super-scanner-software-s3/jupyter-modules/fwdimaging.ipynb

# %%
fp.get_photo(sim=True)
# Out:
# array([[ 152.19718844,  156.73340925,  152.99518826, ...,  151.3393265 ,
#          152.18558258,  147.3414216 ],
#        [ 158.86836904,  159.48018364,  157.95890556, ...,  154.97738507,
#          153.88201386,  158.16756999],
#        [ 155.62888269,  157.69503816,  154.77779607, ...,  149.13612125,
#          152.17104183,  150.77764228],
#        ...,
#        [ 121.61875453,  131.54381035,  132.92237125, ...,  138.62351931,
#          130.45487144,  121.81474081],
#        [ 118.26530928,  115.67156543,  135.61688034, ...,  137.43058532,
#          129.51802354,  106.13302925],
#        [ 132.5644792 ,  120.76017955,  143.85674576, ...,  133.60696834,
#          130.28213072,  115.13856235]])
